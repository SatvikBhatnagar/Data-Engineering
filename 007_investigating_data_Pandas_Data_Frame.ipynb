# %% [markdown]
# Looking at DataFrame Data

# %%
import pandas as pd

# %%
file_path = 'data/business-employment-data-march-2023-quarter-industry-revisions.csv'
df = pd.read_csv(file_path)

# %% [markdown]
# Heads/Tails

# %%
df.head()
# Out:
#    quarter      SER_REF industry_code                        industry_name  \
# 0  2020.09  BDCQ.SEA1AA             A    Agriculture, Forestry and Fishing
# 1  2020.09  BDCQ.SEA1BA             B                               Mining
# 2  2020.09  BDCQ.SEA1CA             C                        Manufacturing
# 3  2020.09  BDCQ.SEA1DA             D  Electricity, Gas, Water and Waste S
# 4  2020.09  BDCQ.SEA1EA             E                         Construction
#
#    filled jobs  filled jobs revised  filled jobs diff  filled jobs % diff  \
# 0        93195                93706               511                 0.5
# 1         5340                 5355                15                 0.3
# 2       217139               218967              1828                 0.8
# 3        19886                20060               174                 0.9
# 4       166413               168095              1682                 1.0
#
# ...

# %%
df.head(3)
# Out:
#    quarter      SER_REF industry_code                      industry_name  \
# 0  2020.09  BDCQ.SEA1AA             A  Agriculture, Forestry and Fishing
# 1  2020.09  BDCQ.SEA1BA             B                             Mining
# 2  2020.09  BDCQ.SEA1CA             C                      Manufacturing
#
#    filled jobs  filled jobs revised  filled jobs diff  filled jobs % diff  \
# 0        93195                93706               511                 0.5
# 1         5340                 5355                15                 0.3
# 2       217139               218967              1828                 0.8
#
#    total_earnings  total earnings revised  earnings diff  earnings % diff
# 0            1205                    1212              7              0.6
# 1             145                     145              0              0.0
# 2            3791                    3823             32              0.8

# %%
df.tail()
# Out:
#      quarter      SER_REF industry_code                      industry_name  \
# 195  2022.12  BDCQ.SEA1PA             P             Education and Training
# 196  2022.12  BDCQ.SEA1QA             Q  Health Care and Social Assistance
# 197  2022.12  BDCQ.SEA1RA             R       Arts and Recreation Services
# 198  2022.12  BDCQ.SEA1SA             S                     Other Services
# 199  2022.12  BDCQ.SEA1ZA             Z                     Total Industry
#
#      filled jobs  filled jobs revised  filled jobs diff  filled jobs % diff  \
# 195       200765               202179              1414                 0.7
# 196       254497               257381              2884                 1.1
# 197        40102                40417               315                 0.8
# 198        73051                73296               245                 0.3
# 199      2233837              2256452             22615                 1.0
#
# ...

# %%
df.tail(2)
# Out:
#      quarter      SER_REF industry_code   industry_name  filled jobs  \
# 198  2022.12  BDCQ.SEA1SA             S  Other Services        73051
# 199  2022.12  BDCQ.SEA1ZA             Z  Total Industry      2233837
#
#      filled jobs revised  filled jobs diff  filled jobs % diff  \
# 198                73296               245                 0.3
# 199              2256452             22615                 1.0
#
#      total_earnings  total earnings revised  earnings diff  earnings % diff
# 198            1037                    1042              5              0.5
# 199           40646                   41068            422              1.0

# %% [markdown]
# Descriptive Statistics

# %%
df.describe()
# Out:
#           quarter   filled jobs  filled jobs revised  filled jobs diff  \
# count   200.00000  2.000000e+02         2.000000e+02        200.000000
# mean   2021.28100  2.156726e+05         2.177362e+05       2063.600000
# std       0.74124  4.521149e+05         4.564216e+05       4410.620442
# min    2020.09000  5.271000e+03         5.295000e+03       -161.000000
# 25%    2021.03000  5.544250e+04         5.624525e+04        404.250000
# 50%    2021.10500  1.033985e+05         1.049300e+05        987.500000
# 75%    2022.06000  1.870135e+05         1.887132e+05       1703.750000
# max    2022.12000  2.233837e+06         2.256452e+06      28071.000000
#
#        filled jobs % diff  total_earnings  total earnings revised  \
# count          200.000000      200.000000              200.000000
# mean             1.028500     3653.040000             3690.325000
# std              0.746474     7684.498263             7762.590183
# ...

# %%
df.min()
# Out:
# quarter                                           2020.09
# SER_REF                                       BDCQ.SEA1AA
# industry_code                                           A
# industry_name             Accommodation and Food Services
# filled jobs                                          5271
# filled jobs revised                                  5295
# filled jobs diff                                     -161
# filled jobs % diff                                   -0.2
# total_earnings                                        140
# total earnings revised                                139
# earnings diff                                          -2
# earnings % diff                                      -0.7
# dtype: object

# %% [markdown]
# Selecting Columns

# %%
df.columns
# Out:
# Index(['quarter', 'SER_REF', 'industry_code', 'industry_name', 'filled jobs',
#        'filled jobs revised', 'filled jobs diff', 'filled jobs % diff',
#        'total_earnings', 'total earnings revised', 'earnings diff',
#        'earnings % diff'],
#       dtype='object')

# %%
df['industry_name']
# Out:
# 0        Agriculture, Forestry and Fishing
# 1                                   Mining
# 2                            Manufacturing
# 3      Electricity, Gas, Water and Waste S
# 4                             Construction
#                       ...
# 195                 Education and Training
# 196      Health Care and Social Assistance
# 197           Arts and Recreation Services
# 198                         Other Services
# 199                         Total Industry
# Name: industry_name, Length: 200, dtype: object

# %%
df[['industry_name', 'earnings diff']]
# Out:
#                            industry_name  earnings diff
# 0      Agriculture, Forestry and Fishing              7
# 1                                 Mining              0
# 2                          Manufacturing             32
# 3    Electricity, Gas, Water and Waste S              5
# 4                           Construction             33
# ..                                   ...            ...
# 195               Education and Training             19
# 196    Health Care and Social Assistance             56
# 197         Arts and Recreation Services              5
# 198                       Other Services              5
# 199                       Total Industry            422
#
# [200 rows x 2 columns]

# %%
df.quarter #if there is no whitespace or special character in the column's name
# Out:
# 0      2020.09
# 1      2020.09
# 2      2020.09
# 3      2020.09
# 4      2020.09
#         ...
# 195    2022.12
# 196    2022.12
# 197    2022.12
# 198    2022.12
# 199    2022.12
# Name: quarter, Length: 200, dtype: float64

# %% [markdown]
# Selecting Columns and Rows

# %% [markdown]
# - iloc operator selects based on index
# - the first argument is the row index

# %%
df.iloc[3]
# Out:
# quarter                                               2020.09
# SER_REF                                           BDCQ.SEA1DA
# industry_code                                               D
# industry_name             Electricity, Gas, Water and Waste S
# filled jobs                                             19886
# filled jobs revised                                     20060
# filled jobs diff                                          174
# filled jobs % diff                                        0.9
# total_earnings                                            493
# total earnings revised                                    498
# earnings diff                                               5
# earnings % diff                                           1.0
# Name: 3, dtype: object

# %%
df.iloc[3:29]
# Out:
#     quarter      SER_REF industry_code                        industry_name  \
# 3   2020.09  BDCQ.SEA1DA             D  Electricity, Gas, Water and Waste S
# 4   2020.09  BDCQ.SEA1EA             E                         Construction
# 5   2020.09  BDCQ.SEA1FA             F                      Wholesale Trade
# 6   2020.09  BDCQ.SEA1GA             G                         Retail Trade
# 7   2020.09  BDCQ.SEA1HA             H      Accommodation and Food Services
# 8   2020.09  BDCQ.SEA1IA             I    Transport, Postal and Warehousing
# 9   2020.09  BDCQ.SEA1JA             J  Information Media and Telecommunica
# 10  2020.09  BDCQ.SEA1KA             K     Financial and Insurance Services
# 11  2020.09  BDCQ.SEA1LA             L  Rental, Hiring and Real Estate Serv
# 12  2020.09  BDCQ.SEA1MA             M  Professional, Scientific and Techni
# 13  2020.09  BDCQ.SEA1NA             N  Administrative and Support Services
# ...

# %%
df.iloc[3:29, 3]
# Out:
# 3     Electricity, Gas, Water and Waste S
# 4                            Construction
# 5                         Wholesale Trade
# 6                            Retail Trade
# 7         Accommodation and Food Services
# 8       Transport, Postal and Warehousing
# 9     Information Media and Telecommunica
# 10       Financial and Insurance Services
# 11    Rental, Hiring and Real Estate Serv
# 12    Professional, Scientific and Techni
# 13    Administrative and Support Services
# 14       Public Administration and Safety
# 15                 Education and Training
# 16      Health Care and Social Assistance
# 17           Arts and Recreation Services
# 18                         Other Services
# 19                         Total Industry
# 20      Agriculture, Forestry and Fishing
# 21                                 Mining
# 22                          Manufacturing
# 23    Electricity, Gas, Water and Waste S
# 24                           Construction
# ...

# %%
df.iloc[3:29, 3:6]
# Out:
#                           industry_name  filled jobs  filled jobs revised
# 3   Electricity, Gas, Water and Waste S        19886                20060
# 4                          Construction       166413               168095
# 5                       Wholesale Trade       103816               104974
# 6                          Retail Trade       197373               198379
# 7       Accommodation and Food Services       138259               139176
# 8     Transport, Postal and Warehousing        84413                85499
# 9   Information Media and Telecommunica        29086                30117
# 10     Financial and Insurance Services        60481                61378
# 11  Rental, Hiring and Real Estate Serv        31360                32203
# 12  Professional, Scientific and Techni       157483               158004
# 13  Administrative and Support Services        93653                94779
# 14     Public Administration and Safety       142530               144919
# ...

# %% [markdown]
# - lock operator uses labels names

# %%
df.head()
# Out:
#    quarter      SER_REF industry_code                        industry_name  \
# 0  2020.09  BDCQ.SEA1AA             A    Agriculture, Forestry and Fishing
# 1  2020.09  BDCQ.SEA1BA             B                               Mining
# 2  2020.09  BDCQ.SEA1CA             C                        Manufacturing
# 3  2020.09  BDCQ.SEA1DA             D  Electricity, Gas, Water and Waste S
# 4  2020.09  BDCQ.SEA1EA             E                         Construction
#
#    filled jobs  filled jobs revised  filled jobs diff  filled jobs % diff  \
# 0        93195                93706               511                 0.5
# 1         5340                 5355                15                 0.3
# 2       217139               218967              1828                 0.8
# 3        19886                20060               174                 0.9
# 4       166413               168095              1682                 1.0
#
# ...

# %%
df.loc[4]
# Out:
# quarter                        2020.09
# SER_REF                    BDCQ.SEA1EA
# industry_code                        E
# industry_name             Construction
# filled jobs                     166413
# filled jobs revised             168095
# filled jobs diff                  1682
# filled jobs % diff                 1.0
# total_earnings                    2873
# total earnings revised            2906
# earnings diff                       33
# earnings % diff                    1.1
# Name: 4, dtype: object

# %%
df.loc[8:15]
# Out:
#     quarter      SER_REF industry_code                        industry_name  \
# 8   2020.09  BDCQ.SEA1IA             I    Transport, Postal and Warehousing
# 9   2020.09  BDCQ.SEA1JA             J  Information Media and Telecommunica
# 10  2020.09  BDCQ.SEA1KA             K     Financial and Insurance Services
# 11  2020.09  BDCQ.SEA1LA             L  Rental, Hiring and Real Estate Serv
# 12  2020.09  BDCQ.SEA1MA             M  Professional, Scientific and Techni
# 13  2020.09  BDCQ.SEA1NA             N  Administrative and Support Services
# 14  2020.09  BDCQ.SEA1OA             O     Public Administration and Safety
# 15  2020.09  BDCQ.SEA1PA             P               Education and Training
#
#     filled jobs  filled jobs revised  filled jobs diff  filled jobs % diff  \
# 8         84413                85499              1086                 1.3
# 9         29086                30117              1031                 3.5
# ...

# %%
df.loc[8:15, 'industry_name']
# Out:
# 8       Transport, Postal and Warehousing
# 9     Information Media and Telecommunica
# 10       Financial and Insurance Services
# 11    Rental, Hiring and Real Estate Serv
# 12    Professional, Scientific and Techni
# 13    Administrative and Support Services
# 14       Public Administration and Safety
# 15                 Education and Training
# Name: industry_name, dtype: object

# %%
df.loc[8:15, ['industry_name','total_earnings']]
# Out:
#                           industry_name  total_earnings
# 8     Transport, Postal and Warehousing            1520
# 9   Information Media and Telecommunica             611
# 10     Financial and Insurance Services            1603
# 11  Rental, Hiring and Real Estate Serv             510
# 12  Professional, Scientific and Techni            3314
# 13  Administrative and Support Services            1121
# 14     Public Administration and Safety            3095
# 15               Education and Training            2994
